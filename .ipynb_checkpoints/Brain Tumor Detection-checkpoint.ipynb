# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import matplotlib.image as mpimg
import pandas as pd
import os
import math
import shutil
import glob

import zipfile
import random
from sklearn.model_selection import train_test_split

# %%
# Unzipping the data

with zipfile.ZipFile('archive (5).zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
data_folder = 'brain_tumor_dataset'

# Ensure the path is valid
if os.path.exists(data_folder):
    inner_folders = ['yes', 'no']
    image_data = []

    # Loop through each inner folder
    for folder in inner_folders:
        # Get the inner folder path
        folder_path = os.path.join(data_folder, folder)

        # Get the list of files in the folder
        files = os.listdir(folder_path)

        # Create touples with image and it's label
        #labeled_images = [(os.path.join(file,), folder) for file in files]
        labeled_images = []
        for image_path in files:
            image_inner_path = os.path.join(folder, image_path)
            full_image_path = os.path.join(data_folder, image_inner_path)
            image = mpimg.imread(full_image_path)
            labeled_images.append((image, folder))

         # Adding the labeled images to the main list 
        image_data.extend(labeled_images)

        print(f"Folder '{folder}' contains {len(labeled_images)} images")
# Out:
# Folder 'yes' contains 155 images
# Folder 'no' contains 98 images

# %%
len(image_data)
# Out:
# 253

# %%
# image_path = 'brain_tumor_dataset/yes/Y1.jpg'
image_path = os.path.join(data_folder, 'yes/Y1.jpg')

# Read the image using Matplotlib
image = mpimg.imread(image_path)

# Display the image using Matplotlib
plt.imshow(image)
plt.title('Brain Tumor Image')
plt.axis('off')  # Turn off axis labels
plt.show()

# %%
image_data_shuffled = random.shuffle(image_data)
image_data
# Out:
# [('Y40.JPG', 'yes'),
#  ('Y36.JPG', 'yes'),
#  ('Y89.JPG', 'yes'),
#  ('Y155.JPG', 'yes'),
#  ('Y13.jpg', 'yes'),
#  ('No18.jpg', 'no'),
#  ('20 no.jpg', 'no'),
#  ('Y257.jpg', 'yes'),
#  ('Y17.jpg', 'yes'),
#  ('1 no.jpeg', 'no'),
#  ('44no.jpg', 'no'),
#  ('Y250.jpg', 'yes'),
#  ('no 90.jpg', 'no'),
#  ('N3.jpg', 'no'),
#  ('no 95.jpg', 'no'),
#  ('Y245.jpg', 'yes'),
#  ('Y33.jpg', 'yes'),
#  ('Y153.jpg', 'yes'),
#  ('Y181.jpg', 'yes'),
#  ('Y65.JPG', 'yes'),
#  ('N20.JPG', 'no'),
#  ('No22.jpg', 'no'),
#  ('Y92.png', 'yes'),
#  ('Y81.jpg', 'yes'),
#  ('3 no.jpg', 'no'),
#  ('Y184.JPG', 'yes'),
#  ('Y243.JPG', 'yes'),
#  ('Y114.JPG', 'yes'),
#  ('Y113.JPG', 'yes'),
#  ('Y16.JPG', 'yes'),
#  ('Y69.jpg', 'yes'),
#  ('15 no.jpg', 'no'),
#  ('Y25.jpg', 'yes'),
#  ('Y95.jpg', 'yes'),
#  ('Y29.jpg', 'yes'),
#  ('8 no.jpg', 'no'),
#  ('Y101.jpg', 'yes'),
#  ('Y169.jpg', 'yes'),
#  ('14 no.jpg', 'no'),
#  ('Y186.jpg', 'yes'),
#  ('32 no.jpg', 'no'),
#  ('Y3.jpg', 'yes'),
#  ('no 96.jpg', 'no'),
#  ('no 923.jpg', 'no'),
#  ('Y59.JPG', 'yes'),
#  ('Y107.jpg', 'yes'),
#  ('Y24.jpg', 'yes'),
#  ('Y2.jpg', 'yes'),
#  ('21 no.jpg', 'no'),
#  ('Y165.JPG', 'yes'),
#  ('Y98.JPG', 'yes'),
#  ('48 no.jpeg', 'no'),
#  ('no 98.jpg', 'no'),
#  ('35 no.jpg', 'no'),
#  ('Y253.JPG', 'yes'),
#  ('Y103.jpg', 'yes'),
#  ('Y11.jpg', 'yes'),
#  ('Y37.jpg', 'yes'),
#  ('Y115.JPG', 'yes'),
#  ('46 no.jpg', 'no'),
#  ('No13.jpg', 'no'),
#  ('N11.jpg', 'no'),
#  ('Y247.JPG', 'yes'),
#  ('no 99.jpg', 'no'),
#  ('Y254.jpg', 'yes'),
#  ('Y158.JPG', 'yes'),
#  ('Y53.jpg', 'yes'),
#  ('31 no.jpg', 'no'),
#  ('Y76.jpg', 'yes'),
#  ('Y73.jpg', 'yes'),
#  ('Y92.jpg', 'yes'),
#  ('Y66.JPG', 'yes'),
#  ('39 no.jpg', 'no'),
#  ('41 no.jpg', 'no'),
#  ('Y18.JPG', 'yes'),
#  ('Y75.JPG', 'yes'),
#  ('45 no.jpg', 'no'),
#  ('Y187.jpg', 'yes'),
#  ('Y44.JPG', 'yes'),
#  ('Y102.jpg', 'yes'),
#  ('no 7.jpeg', 'no'),
#  ('Y258.JPG', 'yes'),
#  ('Y168.jpg', 'yes'),
#  ('No16.jpg', 'no'),
#  ('4 no.jpg', 'no'),
#  ('36 no.jpg', 'no'),
#  ('Y46.jpg', 'yes'),
#  ('Y162.jpg', 'yes'),
#  ('22 no.jpg', 'no'),
#  ('Y56.jpg', 'yes'),
#  ('49 no.jpg', 'no'),
#  ('Y167.JPG', 'yes'),
#  ('Y45.JPG', 'yes'),
#  ('Y252.jpg', 'yes'),
#  ('24 no.jpg', 'no'),
#  ('Y32.jpg', 'yes'),
#  ('Y1.jpg', 'yes'),
#  ('Y108.jpg', 'yes'),
#  ('no 8.jpg', 'no'),
#  ('no 6.jpg', 'no'),
#  ('No14.jpg', 'no'),
#  ('Y4.jpg', 'yes'),
#  ('Y35.jpg', 'yes'),
#  ('N26.JPG', 'no'),
#  ('23 no.jpg', 'no'),
#  ('Y70.jpg', 'yes'),
#  ('Y256.JPG', 'yes'),
#  ('Y60.jpg', 'yes'),
#  ('Y49.JPG', 'yes'),
#  ('N21.jpg', 'no'),
#  ('N6.jpg', 'no'),
#  ('Y112.JPG', 'yes'),
#  ('no 1.jpg', 'no'),
#  ('6 no.jpg', 'no'),
#  ('Y246.JPG', 'yes'),
#  ('no 9.png', 'no'),
#  ('no 94.jpg', 'no'),
#  ('Y161.JPG', 'yes'),
#  ('Y183.jpg', 'yes'),
#  ('17 no.jpg', 'no'),
#  ('Y146.JPG', 'yes'),
#  ('Y71.JPG', 'yes'),
#  ('Y164.JPG', 'yes'),
#  ('Y7.jpg', 'yes'),
#  ('5 no.jpg', 'no'),
#  ('Y163.JPG', 'yes'),
#  ('Y116.JPG', 'yes'),
#  ('Y248.JPG', 'yes'),
#  ('no 89.jpg', 'no'),
#  ('N1.JPG', 'no'),
#  ('Y120.JPG', 'yes'),
#  ('9 no.jpg', 'no'),
#  ('Y51.jpg', 'yes'),
#  ('18 no.jpg', 'no'),
#  ('Y90.jpg', 'yes'),
#  ('Y23.JPG', 'yes'),
#  ('Y74.jpg', 'yes'),
#  ('Y160.JPG', 'yes'),
#  ('No19.jpg', 'no'),
#  ('Y20.jpg', 'yes'),
#  ('Y67.JPG', 'yes'),
#  ('Y255.JPG', 'yes'),
#  ('Y27.jpg', 'yes'),
#  ('Y91.jpg', 'yes'),
#  ('N15.jpg', 'no'),
#  ('Y185.jpg', 'yes'),
#  ('Y30.jpg', 'yes'),
#  ('Y15.jpg', 'yes'),
#  ('Y97.JPG', 'yes'),
#  ('N5.jpg', 'no'),
#  ('Y195.JPG', 'yes'),
#  ('Y147.JPG', 'yes'),
#  ('no 100.jpg', 'no'),
#  ('Y58.JPG', 'yes'),
#  ('50 no.jpg', 'no'),
#  ('Y157.JPG', 'yes'),
#  ('Y188.jpg', 'yes'),
#  ('No20.jpg', 'no'),
#  ('N17.jpg', 'no'),
#  ('Y154.jpg', 'yes'),
#  ('Y26.jpg', 'yes'),
#  ('Y85.JPG', 'yes'),
#  ('28 no.jpg', 'no'),
#  ('no.jpg', 'no'),
#  ('Y50.JPG', 'yes'),
#  ('Y39.jpg', 'yes'),
#  ('no 5.jpeg', 'no'),
#  ('26 no.jpg', 'no'),
#  ('no 91.jpeg', 'no'),
#  ('No12.jpg', 'no'),
#  ('N2.JPG', 'no'),
#  ('Y79.jpg', 'yes'),
#  ('N19.JPG', 'no'),
#  ('Y192.JPG', 'yes'),
#  ('no 92.jpg', 'no'),
#  ('30 no.jpg', 'no'),
#  ('Y251.JPG', 'yes'),
#  ('Y180.jpg', 'yes'),
#  ('47 no.jpg', 'no'),
#  ('No21.jpg', 'no'),
#  ('19 no.jpg', 'no'),
#  ('Y109.JPG', 'yes'),
#  ('13 no.jpg', 'no'),
#  ('Y19.JPG', 'yes'),
#  ('43 no.jpg', 'no'),
#  ('10 no.jpg', 'no'),
#  ('38 no.jpg', 'no'),
#  ('Y52.jpg', 'yes'),
#  ('Y31.jpg', 'yes'),
#  ('Y86.JPG', 'yes'),
#  ('12 no.jpg', 'no'),
#  ('Y54.jpg', 'yes'),
#  ('Y242.JPG', 'yes'),
#  ('No11.jpg', 'no'),
#  ('Y47.JPG', 'yes'),
#  ('Y105.jpg', 'yes'),
#  ('Y12.jpg', 'yes'),
#  ('29 no.jpg', 'no'),
#  ('no 10.jpg', 'no'),
#  ('Y42.jpg', 'yes'),
#  ('N16.jpg', 'no'),
#  ('No17.jpg', 'no'),
#  ('no 4.jpg', 'no'),
#  ('Y104.jpg', 'yes'),
#  ('42 no.jpg', 'no'),
#  ('Y166.JPG', 'yes'),
#  ('Y159.JPG', 'yes'),
#  ('27 no.jpg', 'no'),
#  ('No15.jpg', 'no'),
#  ('Y111.JPG', 'yes'),
#  ('Y14.jpg', 'yes'),
#  ('N22.JPG', 'no'),
#  ('34 no.jpg', 'no'),
#  ('Y55.jpg', 'yes'),
#  ('Y41.jpg', 'yes'),
#  ('Y100.JPG', 'yes'),
#  ('Y38.jpg', 'yes'),
#  ('11 no.jpg', 'no'),
#  ('Y28.jpg', 'yes'),
#  ('Y148.JPG', 'yes'),
#  ('Y82.jpg', 'yes'),
#  ('2 no.jpeg', 'no'),
#  ('Y170.JPG', 'yes'),
#  ('Y61.jpg', 'yes'),
#  ('Y194.jpg', 'yes'),
#  ('Y106.jpg', 'yes'),
#  ('Y99.JPG', 'yes'),
#  ('Y21.jpg', 'yes'),
#  ('Y182.JPG', 'yes'),
#  ('Y156.JPG', 'yes'),
#  ('Y117.JPG', 'yes'),
#  ('Y249.JPG', 'yes'),
#  ('7 no.jpg', 'no'),
#  ('Y96.jpg', 'yes'),
#  ('Y22.jpg', 'yes'),
#  ('Y78.jpg', 'yes'),
#  ('25 no.jpg', 'no'),
#  ('Y77.jpg', 'yes'),
#  ('no 2.jpg', 'no'),
#  ('Y193.JPG', 'yes'),
#  ('Y10.jpg', 'yes'),
#  ('Y8.jpg', 'yes'),
#  ('Y6.jpg', 'yes'),
#  ('no 97.jpg', 'no'),
#  ('Y9.jpg', 'yes'),
#  ('40 no.jpg', 'no'),
#  ('Y259.JPG', 'yes'),
#  ('Y244.JPG', 'yes'),
#  ('Y62.jpg', 'yes'),
#  ('33 no.jpg', 'no'),
#  ('Y34.jpg', 'yes'),
#  ('no 3.jpg', 'no'),
#  ('37 no.jpg', 'no')]

# %%
train_size = 0.7
validation_size = 0.15
test_size = 0.15

train_set, test_set = train_test_split(image_data, test_size=1 - train_size, random_state=42)
validation_set, test_set = train_test_split(test_set, test_size=test_size/(test_size + validation_size), random_state=42)

print("Train set size:", len(train_set))
print("Validation set size:", len(validation_set))
print("Test set size:", len(test_set))
# Out:
# Train set size: 177
# Validation set size: 38
# Test set size: 38

# %%
yes_pictures = [picture for picture in train_set if picture[1] == 'yes']
no_pictures = [picture for picture in train_set if picture[1] == 'no']

print(f"Number of positive cases in train set is: {len(yes_pictures)}")
print(f"Number of negative cases in train set is: {len(no_pictures)}")
# Out:
# Number of positive cases in train set is: 109
# Number of negative cases in train set is: 68

# %%
# Out:
# [('Y10.jpg', 'yes'),
#  ('Y16.JPG', 'yes'),
#  ('Y100.JPG', 'yes'),
#  ('Y168.jpg', 'yes'),
#  ('Y112.JPG', 'yes'),
#  ('Y11.jpg', 'yes'),
#  ('Y51.jpg', 'yes'),
#  ('Y158.JPG', 'yes'),
#  ('Y38.jpg', 'yes'),
#  ('Y22.jpg', 'yes'),
#  ('Y113.JPG', 'yes'),
#  ('Y92.png', 'yes'),
#  ('Y163.JPG', 'yes'),
#  ('Y252.jpg', 'yes'),
#  ('Y62.jpg', 'yes'),
#  ('Y77.jpg', 'yes'),
#  ('Y32.jpg', 'yes'),
#  ('Y30.jpg', 'yes'),
#  ('Y193.JPG', 'yes'),
#  ('Y3.jpg', 'yes'),
#  ('Y157.JPG', 'yes'),
#  ('Y44.JPG', 'yes'),
#  ('Y195.JPG', 'yes'),
#  ('Y243.JPG', 'yes'),
#  ('Y9.jpg', 'yes'),
#  ('Y183.jpg', 'yes'),
#  ('Y106.jpg', 'yes'),
#  ('Y67.JPG', 'yes'),
#  ('Y40.JPG', 'yes'),
#  ('Y89.JPG', 'yes'),
#  ('Y187.jpg', 'yes'),
#  ('Y24.jpg', 'yes'),
#  ('Y101.jpg', 'yes'),
#  ('Y39.jpg', 'yes'),
#  ('Y27.jpg', 'yes'),
#  ('Y250.jpg', 'yes'),
#  ('Y244.JPG', 'yes'),
#  ('Y114.JPG', 'yes'),
#  ('Y188.jpg', 'yes'),
#  ('Y13.jpg', 'yes'),
#  ('Y164.JPG', 'yes'),
#  ('Y25.jpg', 'yes'),
#  ('Y15.jpg', 'yes'),
#  ('Y109.JPG', 'yes'),
#  ('Y247.JPG', 'yes'),
#  ('Y23.JPG', 'yes'),
#  ('Y156.JPG', 'yes'),
#  ('Y242.JPG', 'yes'),
#  ('Y92.jpg', 'yes'),
#  ('Y105.jpg', 'yes'),
#  ('Y254.jpg', 'yes'),
#  ('Y59.JPG', 'yes'),
#  ('Y50.JPG', 'yes'),
#  ('Y7.jpg', 'yes'),
#  ('Y58.JPG', 'yes'),
#  ('Y81.jpg', 'yes'),
#  ('Y258.JPG', 'yes'),
#  ('Y186.jpg', 'yes'),
#  ('Y2.jpg', 'yes'),
#  ('Y85.JPG', 'yes'),
#  ('Y185.jpg', 'yes'),
#  ('Y19.JPG', 'yes'),
#  ('Y155.JPG', 'yes'),
#  ('Y70.jpg', 'yes'),
#  ('Y117.JPG', 'yes'),
#  ('Y12.jpg', 'yes'),
#  ('Y78.jpg', 'yes'),
#  ('Y165.JPG', 'yes'),
#  ('Y29.jpg', 'yes'),
#  ('Y111.JPG', 'yes'),
#  ('Y257.jpg', 'yes'),
#  ('Y79.jpg', 'yes'),
#  ('Y167.JPG', 'yes'),
#  ('Y99.JPG', 'yes'),
#  ('Y249.JPG', 'yes'),
#  ('Y56.jpg', 'yes'),
#  ('Y17.jpg', 'yes'),
#  ('Y28.jpg', 'yes'),
#  ('Y153.jpg', 'yes'),
#  ('Y61.jpg', 'yes'),
#  ('Y90.jpg', 'yes'),
#  ('Y55.jpg', 'yes'),
#  ('Y96.jpg', 'yes'),
#  ('Y253.JPG', 'yes'),
#  ('Y60.jpg', 'yes'),
#  ('Y98.JPG', 'yes'),
#  ('Y6.jpg', 'yes'),
#  ('Y86.JPG', 'yes'),
#  ('Y194.jpg', 'yes'),
#  ('Y115.JPG', 'yes'),
#  ('Y37.jpg', 'yes'),
#  ('Y104.jpg', 'yes'),
#  ('Y26.jpg', 'yes'),
#  ('Y52.jpg', 'yes'),
#  ('Y54.jpg', 'yes'),
#  ('Y169.jpg', 'yes'),
#  ('Y36.JPG', 'yes'),
#  ('Y120.JPG', 'yes'),
#  ('Y147.JPG', 'yes'),
#  ('Y162.jpg', 'yes'),
#  ('Y18.JPG', 'yes'),
#  ('Y41.jpg', 'yes'),
#  ('Y14.jpg', 'yes'),
#  ('Y71.JPG', 'yes'),
#  ('Y31.jpg', 'yes'),
#  ('Y66.JPG', 'yes'),
#  ('Y256.JPG', 'yes'),
#  ('Y45.JPG', 'yes'),
#  ('Y35.jpg', 'yes')]
